# %% [markdown]
# <a href="https://colab.research.google.com/github/Buntariga2545/Data-mining/blob/main/Project_Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel('/content/drive/My Drive/Paper/Data-Survey-13-7-2023.xlsx')
data
# Out:
#         No               วันที่   เพศ  อายุ  น้ำหนัก  ส่วนสูง        BMI  \
# 0      NaN                  NaN   NaN   NaN      NaN      NaN        NaN
# 1      1.0  2022-12-28 00:00:00   ชาย  27.0     49.0    169.0  17.156262
# 2      2.0  2022-12-28 00:00:00   ชาย  36.0     71.0    175.0  23.183673
# 3      3.0  2022-12-28 00:00:00  หญิง  25.0     89.0    153.0  38.019565
# 4      4.0  2022-12-28 00:00:00   ชาย  29.0     75.0    165.0  27.548209
# ..     ...                  ...   ...   ...      ...      ...        ...
# 189  189.0           13/05/2023   ชาย  37.0     88.0    180.0  27.160494
# 190  190.0           13/05/2023  หญิง  23.0     47.0    159.0  18.591037
# 191  191.0           13/05/2023   ชาย  27.0     47.0    169.0  16.456006
# 192  192.0           13/05/2023   ชาย  57.0     68.0    171.0  23.255019
# 193  193.0           13/05/2023  หญิง  64.0     47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา ค่าที่เครื่องวัดได้  ...  \
# ...

# %%
data = pd.read_excel('/content/drive/My Drive/Paper/Data-Survey-13-7-2023.xlsx', skiprows = 1)
data
# Out:
#      Unnamed: 0           Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0             1  2022-12-28 00:00:00        ชาย          27        49.0
# 1             2  2022-12-28 00:00:00        ชาย          36        71.0
# 2             3  2022-12-28 00:00:00       หญิง          25        89.0
# 3             4  2022-12-28 00:00:00        ชาย          29        75.0
# 4             5  2022-12-28 00:00:00        ชาย          28       118.0
# ..          ...                  ...        ...         ...         ...
# 188         189           13/05/2023        ชาย          37        88.0
# 189         190           13/05/2023       หญิง          23        47.0
# 190         191           13/05/2023        ชาย          27        47.0
# 191         192           13/05/2023        ชาย          57        68.0
# 192         193           13/05/2023       หญิง          64        47.0
#
#      Unnamed: 5  Unnamed: 6            Unnamed: 7 Unnamed: 8  Temp  ...  \
# ...

# %%
data.rename(columns = {'Unnamed: 0' : 'No', 'Unnamed: 1' : 'วันที่', 'Unnamed: 2' : 'Sex', 'Unnamed: 3' : 'Age', 'Unnamed: 4' : 'Weight',
                       'Unnamed: 5' : 'Height', 'Unnamed: 6' : 'BMI', 'Unnamed: 7' : 'พื้นที่ทำแบบสอบถาม', 'Unnamed: 8' : 'เวลา',
                       'Unnamed: 18' : 'Thermal acceptance', 'Unnamed: 26' : 'Thermal sensation Vote'
                       }, inplace = True)
data
# Out:
#       No               วันที่   Sex  Age  Weight  Height        BMI  \
# 0      1  2022-12-28 00:00:00   ชาย   27    49.0   169.0  17.156262
# 1      2  2022-12-28 00:00:00   ชาย   36    71.0   175.0  23.183673
# 2      3  2022-12-28 00:00:00  หญิง   25    89.0   153.0  38.019565
# 3      4  2022-12-28 00:00:00   ชาย   29    75.0   165.0  27.548209
# 4      5  2022-12-28 00:00:00   ชาย   28   118.0   187.0  33.744173
# ..   ...                  ...   ...  ...     ...     ...        ...
# 188  189           13/05/2023   ชาย   37    88.0   180.0  27.160494
# 189  190           13/05/2023  หญิง   23    47.0   159.0  18.591037
# 190  191           13/05/2023   ชาย   27    47.0   169.0  16.456006
# 191  192           13/05/2023   ชาย   57    68.0   171.0  23.255019
# 192  193           13/05/2023  หญิง   64    47.0   149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %%
data.isna().sum()
# Out:
# No                        0
# วันที่                    0
# Sex                       0
# Age                       0
# Weight                    0
# Height                    0
# BMI                       0
# พื้นที่ทำแบบสอบถาม        0
# เวลา                      0
# Temp                      0
# Globe temp                0
# %RH                       0
# V (m/s)                   0
# วงเล็บ 1                  0
# สมการหลัง บวก             0
# วงเล็บ 2                  0
# ยกกำลัง 1 ส่วน 4/ 0.25    0
# ลบ 273.15                 0
# Thermal acceptance        0
# Thermal sensation Vote    0
# อุณหภูมิ                  0
# ความชื้น                  0
# กระแสลม                   0
# ความแรงของแสงแดด          0
# เหงื่อบริเวณผิวหนัง       0
# ความร้อน                  0
# ความชื้น.1                0
# กระแสลม.1                 0
# แสงแดด                    0
# เหงื่อบริเวณผิวหนัง.1     0
# dtype: int64

# %% [markdown]
# ##แทนค่า missing value ด้วย KNN

# %%
from sklearn.impute import KNNImputer

imputer = KNNImputer(n_neighbors=5)
imputed = imputer.fit_transform(data[['Weight', 'Height']])
imputed[163:168]
# Out:
# array([[ 78.        , 185.        ],
#        [ 65.        , 169.        ],
#        [ 68.54450262, 167.33507853],
#        [ 64.        , 154.        ],
#        [ 65.        , 150.        ]])

# %%
imputed[123:130]
# Out:
# array([[ 49.        , 169.        ],
#        [ 46.        , 155.        ],
#        [ 63.        , 173.        ],
#        [ 89.        , 153.        ],
#        [ 68.54450262, 167.33507853],
#        [ 62.        , 163.        ],
#        [ 60.        , 155.        ]])

# %%
data.Weight.fillna(68, inplace=True)
data.Height.fillna(167, inplace=True)

# %%
BMI1 = 68/(1.67**2)
BMI1
# Out:
# 24.38237297859371

# %%
data.BMI.fillna(BMI1, inplace=True)

# %%
data.shape
# Out:
# (193, 30)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No                      193 non-null    int64
#  1   วันที่                  193 non-null    object
#  2   Sex                     193 non-null    object
#  3   Age                     193 non-null    int64
#  4   Weight                  193 non-null    float64
#  5   Height                  193 non-null    float64
#  6   BMI                     193 non-null    float64
#  7   พื้นที่ทำแบบสอบถาม      193 non-null    object
#  8   เวลา                    193 non-null    object
#  9   Temp                    193 non-null    float64
#  10  Globe temp              193 non-null    float64
#  11  %RH                     193 non-null    float64
#  12  V (m/s)                 193 non-null    float64
#  13  วงเล็บ 1                193 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# No                        0
# วันที่                    0
# Sex                       0
# Age                       0
# Weight                    0
# Height                    0
# BMI                       0
# พื้นที่ทำแบบสอบถาม        0
# เวลา                      0
# Temp                      0
# Globe temp                0
# %RH                       0
# V (m/s)                   0
# วงเล็บ 1                  0
# สมการหลัง บวก             0
# วงเล็บ 2                  0
# ยกกำลัง 1 ส่วน 4/ 0.25    0
# ลบ 273.15                 0
# Thermal acceptance        0
# Thermal sensation Vote    0
# อุณหภูมิ                  0
# ความชื้น                  0
# กระแสลม                   0
# ความแรงของแสงแดด          0
# เหงื่อบริเวณผิวหนัง       0
# ความร้อน                  0
# ความชื้น.1                0
# กระแสลม.1                 0
# แสงแดด                    0
# เหงื่อบริเวณผิวหนัง.1     0
# dtype: int64

# %%
data.describe()
# Out:
#                No         Age      Weight      Height         BMI        Temp  \
# count  193.000000  193.000000  193.000000  193.000000  193.000000  193.000000
# mean    97.000000   30.720207   68.538860  167.331606   24.364511   30.895337
# std     55.858452   11.950177   22.290455    9.716496    7.089200    2.310264
# min      1.000000   20.000000   41.000000  144.000000   16.015625   27.200000
# 25%     49.000000   25.000000   49.000000  159.000000   19.146722   29.100000
# 50%     97.000000   27.000000   63.000000  169.000000   22.343516   30.800000
# 75%    145.000000   36.000000   75.000000  173.000000   27.548209   32.700000
# max    193.000000   70.000000  147.000000  187.000000   48.553310   35.600000
#
#        Globe temp         %RH     V (m/s)      วงเล็บ 1  ...    อุณหภูมิ  \
# count  193.000000  193.000000  193.000000  1.930000e+02  ...  193.000000
# mean    31.533161   48.780829    0.265311  8.621030e+09  ...    2.559585
# ...

# %% [markdown]
# ##drop ข้อมูลที่เป็นค่าว่างจำนวน 3 ค่าออกไปก่อน

# %%
data.drop([-3, -2, -1, 0, '+1', '+2', '+3'], axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(data['Weight'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f746cee3460>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f746cee39a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f746cee31c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f746cee3ee0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f746bf0fb20>],
#  'means': []}

# %%
plt.boxplot(data['ส่วนสูง'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f746cb09810>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f746cb09d50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f746f4c36d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f746cb0a290>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f746cb0a530>],
#  'means': []}

# %%
plt.boxplot(data['BMI'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f746cbc5bd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f746cbc6110>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f746cbc5930>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f746cbc6650>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f746cbc68f0>],
#  'means': []}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data.describe(include=np.object)
# Out:
# <ipython-input-131-289c2ff97710>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.describe(include=np.object)
#             วันที่    พื้นที่ทำแบบสอบถาม    เวลา Thermal acceptance
# count          193                   193  193.00                193
# unique           4                     6   46.00                  2
# top     13/05/2023  ภายนอก/ มีหลังคาคลุม   16.26             Accept
# freq            66                   107    9.00                172

# %% [markdown]
# ##records ที่เป็นผู้ชาย จากทั้งหมด

# %%
data[data['เพศ']=='ชาย']
# Out:
#       No               วันที่  เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00  ชาย    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00  ชาย    36    71.0    175.0  23.183673
# 3      4  2022-12-28 00:00:00  ชาย    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00  ชาย    28   118.0    187.0  33.744173
# 5      6  2022-12-28 00:00:00  ชาย    27    49.0    169.0  17.156262
# ..   ...                  ...  ...   ...     ...      ...        ...
# 182  183           13/05/2023  ชาย    25    81.0    181.0  24.724520
# 187  188           13/05/2023  ชาย    27    72.0    171.0  24.622961
# 188  189           13/05/2023  ชาย    37    88.0    180.0  27.160494
# 190  191           13/05/2023  ชาย    27    47.0    169.0  16.456006
# 191  192           13/05/2023  ชาย    57    68.0    171.0  23.255019
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %% [markdown]
# ##records ที่เป็นผู้หญิง จากทั้งหมด

# %%
data[data['เพศ']=='หญิง']
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 2      3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 6      7  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 14    15  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 16    17  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 20    21  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# ..   ...                  ...   ...   ...     ...      ...        ...
# 184  185           13/05/2023  หญิง    62    45.0    144.0  21.701389
# 185  186           13/05/2023  หญิง    35    65.0    157.0  26.370238
# 186  187           13/05/2023  หญิง    62    54.0    150.0  24.000000
# 189  190           13/05/2023  หญิง    23    47.0    159.0  18.591037
# 192  193           13/05/2023  หญิง    64    47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %% [markdown]
# ##แทนค่าลักษณะของคำที่เหมือนกัน

# %%
set(data['พื้นที่ทำแบบสอบถาม'])
# Out:
# {'ภายนอก / ใต้ร่มไม้',
#  'ภายนอก กลางแจ้ง',
#  'ภายนอก/ กลางแจ้ง',
#  'ภายนอก/ มีหลังคาคลุม',
#  'ภายใต้ร่มไม้',
#  'ภายใต้อาคาร'}

# %%
data['พื้นที่ทำแบบสอบถาม'][data['พื้นที่ทำแบบสอบถาม']=='ภายใต้ร่มไม้'] = 'ภายนอก / ใต้ร่มไม้'
data['พื้นที่ทำแบบสอบถาม'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก กลางแจ้ง'] = 'ภายนอก/ กลางแจ้ง'
# Out:
# <ipython-input-100-daf20139a280>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['พื้นที่ทำแบบสอบถาม'][data['พื้นที่ทำแบบสอบถาม']=='ภายใต้ร่มไม้'] = 'ภายนอก / ใต้ร่มไม้'
# <ipython-input-100-daf20139a280>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['พื้นที่ทำแบบสอบถาม'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก กลางแจ้ง'] = 'ภายนอก/ กลางแจ้ง'

# %%
set(data['พื้นที่ทำแบบสอบถาม'])
# Out:
# {'ภายนอก / ใต้ร่มไม้',
#  'ภายนอก/ กลางแจ้ง',
#  'ภายนอก/ มีหลังคาคลุม',
#  'ภายใต้อาคาร'}

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No                      193 non-null    int64
#  1   วันที่                  193 non-null    object
#  2   เพศ                     193 non-null    object
#  3   อายุ                    193 non-null    int64
#  4   Weight                  193 non-null    float64
#  5   ส่วนสูง                 193 non-null    float64
#  6   BMI                     193 non-null    float64
#  7   พื้นที่ทำแบบสอบถาม      193 non-null    object
#  8   เวลา                    193 non-null    object
#  9   Temp                    193 non-null    float64
#  10  Globe temp              193 non-null    float64
#  11  %RH                     193 non-null    float64
#  12  V (m/s)                 193 non-null    float64
#  13  วงเล็บ 1                193 non-null    int64
# ...

# %% [markdown]
# ##เปลี่ยนวันที่เป็น datetime

# %%
set(data['วันที่'])
# Out:
# {'13/05/2023',
#  datetime.datetime(2022, 12, 28, 0, 0),
#  datetime.datetime(2023, 1, 6, 0, 0),
#  datetime.datetime(2023, 1, 8, 0, 0)}

# %%
data['วันที่'] = pd.to_datetime(data.วันที่)
# Out:
# <ipython-input-104-4844d76cbacc>:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['วันที่'] = pd.to_datetime(data.วันที่)

# %%
set(data['วันที่'])
# Out:
# {Timestamp('2022-12-28 00:00:00'),
#  Timestamp('2023-01-06 00:00:00'),
#  Timestamp('2023-01-08 00:00:00'),
#  Timestamp('2023-05-13 00:00:00')}

# %% [markdown]
# #Visualizations

# %%
import seaborn as sns

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %% [markdown]
# ##plot แสดงเพศและอายุเฉลี่ยของผู้ตอบแบบสอบถาม

# %%
data.groupby('เพศ').mean()
# Out:
# <ipython-input-109-b457c83e3db3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('เพศ').mean()
#               No       อายุ  Weight     ส่วนสูง        BMI       Temp  \
# เพศ
# ชาย    84.024000  28.832000  71.008  171.872000  23.561918  30.375200
# หญิง  120.852941  34.191176  63.000  156.529412  25.839867  31.851471
#
#       Globe temp        %RH  V (m/s)      วงเล็บ 1  ...  อุณหภูมิ  ความชื้น  \
# เพศ                                                 ...
# ชาย    31.004000  46.783200  0.27160  8.560942e+09  ...  2.288000  1.944000
# หญิง   32.505882  52.452941  0.25375  8.731485e+09  ...  3.058824  2.073529
#
#        กระแสลม  ความแรงของแสงแดด  เหงื่อบริเวณผิวหนัง  ความร้อน  ความชื้น.1  \
# เพศ
# ชาย   2.312000             1.776             1.840000 -0.672000   -0.168000
# ...

# %%
data31 = data.groupby('เพศ').mean().reset_index()[['เพศ','อายุ']]
data31.sort_values(by=['อายุ'])
# Out:
# <ipython-input-110-2e1778dfa4f0>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data31 = data.groupby('เพศ').mean().reset_index()[['เพศ','อายุ']]
#     เพศ       อายุ
# 0   ชาย  28.832000
# 1  หญิง  34.191176

# %%
sns.barplot(x='เพศ', y='อายุ', data=data31)
# Out:
# <Axes: xlabel='เพศ', ylabel='อายุ'>

# %% [markdown]
# ##histogram อายุของแต่ละเพศ แสดงให้เห็นภาพรวม ค่าสูง ค่าต่ำ ค่ากลาง การกระจาย

# %%
data['อายุ'][data['เพศ']=='ชาย'].hist(label="male", alpha=0.5)
data['อายุ'][data['เพศ']=='หญิง'].hist(label="female", alpha=0.5)
plt.legend(loc='upper right')

# %% [markdown]
# ##plot แสดงเพศและอุณหภูมิเฉลี่ยของผู้ตอบแบบสอบถาม

# %%
data.groupby('เพศ').mean()
# Out:
# <ipython-input-116-b457c83e3db3>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('เพศ').mean()
#               No       อายุ  Weight     ส่วนสูง        BMI       Temp  \
# เพศ
# ชาย    84.024000  28.832000  71.008  171.872000  23.561918  30.375200
# หญิง  120.852941  34.191176  63.000  156.529412  25.839867  31.851471
#
#       Globe temp        %RH  V (m/s)      วงเล็บ 1  ...  อุณหภูมิ  ความชื้น  \
# เพศ                                                 ...
# ชาย    31.004000  46.783200  0.27160  8.560942e+09  ...  2.288000  1.944000
# หญิง   32.505882  52.452941  0.25375  8.731485e+09  ...  3.058824  2.073529
#
#        กระแสลม  ความแรงของแสงแดด  เหงื่อบริเวณผิวหนัง  ความร้อน  ความชื้น.1  \
# เพศ
# ชาย   2.312000             1.776             1.840000 -0.672000   -0.168000
# ...

# %%
data32 = data.groupby('เพศ').mean().reset_index()[['เพศ','Temp']]
data32.sort_values(by=['Temp'])
# Out:
# <ipython-input-117-eb86c71638d4>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data32 = data.groupby('เพศ').mean().reset_index()[['เพศ','Temp']]
#     เพศ       Temp
# 0   ชาย  30.375200
# 1  หญิง  31.851471

# %% [markdown]
# ##histogram อุณหภูมิบริเวณที่ทำแบบสอบถามของแต่ละเพศ แสดงให้เห็นภาพรวม ค่าสูง ค่าต่ำ ค่ากลาง การกระจาย

# %%
data['Temp'][data['เพศ']=='ชาย'].hist(label="male", alpha=0.5)
data['Temp'][data['เพศ']=='หญิง'].hist(label="female", alpha=0.5)
plt.legend(loc='upper right')

# %% [markdown]
# ##plot แสดงพื้นที่ทำแบบสอบถามและอุณหภูมิเฉลี่ยของผู้ตอบแบบสอบถาม

# %%
data.groupby('พื้นที่ทำแบบสอบถาม').mean()
# Out:
# <ipython-input-122-bbc1fd0e3090>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby('พื้นที่ทำแบบสอบถาม').mean()
#                               No       อายุ     Weight     ส่วนสูง        BMI  \
# พื้นที่ทำแบบสอบถาม
# ภายนอก / ใต้ร่มไม้    138.733333  30.866667  60.333333  163.066667  22.858977
# ภายนอก/ กลางแจ้ง      101.888889  25.777778  67.888889  169.777778  23.445335
# ภายนอก/ มีหลังคาคลุม   61.046729  26.364486  72.364486  169.364486  25.157033
# ภายใต้อาคาร           156.113208  41.150943  62.075472  160.452830  23.502782
#
#                            Temp  Globe temp        %RH   V (m/s)  \
# พื้นที่ทำแบบสอบถาม
# ภายนอก / ใต้ร่มไม้    32.100000   32.646667  50.213333  0.240667
# ภายนอก/ กลางแจ้ง      31.250000   31.544444  47.188889  0.215278
# ...

# %%
data33 = data.groupby('พื้นที่ทำแบบสอบถาม').mean().reset_index()[['พื้นที่ทำแบบสอบถาม','Temp']]
data33.sort_values(by=['Temp'])
# Out:
# <ipython-input-123-74ef34d6b46f>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data33 = data.groupby('พื้นที่ทำแบบสอบถาม').mean().reset_index()[['พื้นที่ทำแบบสอบถาม','Temp']]
#      พื้นที่ทำแบบสอบถาม       Temp
# 2  ภายนอก/ มีหลังคาคลุม  29.472897
# 1      ภายนอก/ กลางแจ้ง  31.250000
# 0    ภายนอก / ใต้ร่มไม้  32.100000
# 3           ภายใต้อาคาร  33.305660

# %% [markdown]
# ##histogram อุณหภูมิบริเวณที่ทำแบบสอบถามของแต่ละพื้นที่ทำแบบสอบถาม แสดงให้เห็นภาพรวม ค่าสูง ค่าต่ำ ค่ากลาง การกระจาย

# %%
figure, axis = plt.subplots(2, 2)

axis[0, 0].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก / ใต้ร่มไม้'], color='red', alpha=0.5)
axis[0, 0].set_title('ภายนอก / ใต้ร่มไม้')
axis[0, 1].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ กลางแจ้ง'], color='green', alpha=0.5)
axis[0, 1].set_title('ภายนอก/ กลางแจ้ง')
axis[1, 0].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ มีหลังคาคลุม'], color='purple', alpha=0.5)
axis[1, 0].set_title('ภายนอก/ มีหลังคาคลุม')
axis[1, 1].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายใต้อาคาร'], color='blue', alpha=0.5)
axis[1, 1].set_title('ภายใต้อาคาร')
plt.legend(loc='upper right')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
figure, axis = plt.subplots(1, 2, figsize=(5.5, 3.5), layout="constrained")

axis[0].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก / ใต้ร่มไม้'], color='red', alpha=0.5)
axis[0].set_title('ภายนอก / ใต้ร่มไม้')
axis[1].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ กลางแจ้ง'], color='green', alpha=0.5)
axis[1].set_title('ภายนอก/ กลางแจ้ง')

plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
figure, axis = plt.subplots(1, 2, figsize=(5.5, 3.5), layout="constrained")

axis[0].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ มีหลังคาคลุม'], color='purple', alpha=0.5)
axis[0].set_title('ภายนอก/ มีหลังคาคลุม')
axis[1].hist(data['Temp'][data['พื้นที่ทำแบบสอบถาม']=='ภายใต้อาคาร'], color='blue', alpha=0.5)
axis[1].set_title('ภายใต้อาคาร')
plt.legend(loc='upper right')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##plot แสดงจำนวนที่ผู้ตอบแบบสอบถามที่ยอมรับสภาพอากาศและไม่ยอมรับสภาพอากาศ

# %%
count_pv_onset = data.groupby('Thermal acceptance')[['No']].count().sort_values('No', ascending=False)
count_pv_onset
# Out:
#                      No
# Thermal acceptance
# Accept              172
# Unaccept             21

# %%
count_pv_onset.plot.pie(y='No')
# Out:
# <Axes: ylabel='No'>

# %%
data['Age'][data['Thermal acceptance']=='Accept'].hist(label="Accept", alpha=0.5)
data['Age'][data['Thermal acceptance']=='Unaccept'].hist(label="Unaccept", alpha=0.5)
plt.legend(loc='upper right')

# %%
data['Weight'][data['Thermal acceptance']=='Accept'].hist(label="Accept", alpha=0.5)
data['Weight'][data['Thermal acceptance']=='Unaccept'].hist(label="Unaccept", alpha=0.5)
plt.legend(loc='upper right')

# %%
data['Sex'][data['Thermal acceptance']=='Accept'].hist(label="Accept", alpha=0.5)
data['Sex'][data['Thermal acceptance']=='Unaccept'].hist(label="Unaccept", alpha=0.5)
plt.legend(loc='upper right')

# %%
figure, axis = plt.subplots(1, 2, figsize=(5.5, 3.5), layout="constrained")

axis[0].hist(data['Temp'][data['Thermal acceptance']=='Accept'], color='red', alpha=0.5)
axis[0].set_title('Accept')
axis[1].hist(data['Temp'][data['Thermal acceptance']=='Unaccept'], color='green', alpha=0.5)
axis[1].set_title('Unaccept')

plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data['Temp'][data['Thermal acceptance']=='Accept'].hist(label="Accept", alpha=0.5)
data['Temp'][data['Thermal acceptance']=='Unaccept'].hist(label="Unaccept", alpha=0.5)
plt.legend(loc='upper right')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.histplot(x='Thermal sensation Vote', data=data, kde=True, hue='Thermal acceptance')

plt.show()

# %% [markdown]
# ##กราฟแสดงปัจจัยด้านสภาพอากาศต่อThermal acceptance

# %%
figure, axis = plt.subplots(1, 2, figsize=(6, 4), layout="constrained")

sns.histplot(data=data, x="อุณหภูมิ", kde=True, hue='Thermal acceptance', ax=axis[0])
sns.histplot(data=data, x="ความชื้น", kde=True, hue='Thermal acceptance', ax=axis[1])

plt.show()

# %%
figure, axis = plt.subplots(1, 2, figsize=(6, 4), layout="constrained")

sns.histplot(data=data, x="กระแสลม", kde=True, hue='Thermal acceptance', ax=axis[0])
sns.histplot(data=data, x="ความแรงของแสงแดด", kde=True, hue='Thermal acceptance', ax=axis[1])

plt.show()

# %%
figure, axis = plt.subplots(1, 2, figsize=(6, 4), layout="constrained")

sns.histplot(data=data, x="เหงื่อบริเวณผิวหนัง", kde=True, hue='Thermal acceptance', ax=axis[0])
sns.histplot(data=data, x="เหงื่อบริเวณผิวหนัง.1", kde=True, hue='Thermal acceptance', ax=axis[1])

plt.show()

# %%
figure, axis = plt.subplots(1, 2, figsize=(6, 4), layout="constrained")

sns.histplot(data=data, x="ความร้อน", kde=True, hue='Thermal acceptance', ax=axis[0])
sns.histplot(data=data, x="ความชื้น.1", kde=True, hue='Thermal acceptance', ax=axis[1])

plt.show()

# %%
figure, axis = plt.subplots(1, 2, figsize=(6, 4), layout="constrained")

sns.histplot(data=data, x="กระแสลม.1", kde=True, hue='Thermal acceptance', ax=axis[0])
sns.histplot(data=data, x="แสงแดด", kde=True, hue='Thermal acceptance', ax=axis[1])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.histplot(x='Temp', data=data, kde=True, hue='Thermal sensation Vote')

plt.show()

# %% [markdown]
# ##สร้าง columns ใหม่ ชื่อ TMRT โดยหาจากสูตร ใช้ค่าของ Temp, Globe Temp, %RH, V

# %%
data["TMRT"] = data['ยกกำลัง 1 ส่วน 4/ 0.25'] - data['ลบ 273.15']
data
# Out:
#       No               วันที่   Sex  Age  Weight  Height        BMI  \
# 0      1  2022-12-28 00:00:00   ชาย   27    49.0   169.0  17.156262
# 1      2  2022-12-28 00:00:00   ชาย   36    71.0   175.0  23.183673
# 2      3  2022-12-28 00:00:00  หญิง   25    89.0   153.0  38.019565
# 3      4  2022-12-28 00:00:00   ชาย   29    75.0   165.0  27.548209
# 4      5  2022-12-28 00:00:00   ชาย   28   118.0   187.0  33.744173
# ..   ...                  ...   ...  ...     ...     ...        ...
# 188  189           13/05/2023   ชาย   37    88.0   180.0  27.160494
# 189  190           13/05/2023  หญิง   23    47.0   159.0  18.591037
# 190  191           13/05/2023   ชาย   27    47.0   169.0  16.456006
# 191  192           13/05/2023   ชาย   57    68.0   171.0  23.255019
# 192  193           13/05/2023  หญิง   64    47.0   149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  ความชื้น  กระแสลม  \
# 0    ภายนอก/ มีหลังคาคลุม  10:55 AM  30.5  ...         1        2
# ...

# %%
df = {'ชาย':1, 'หญิง':2}
data = data.copy()
for i in range(2,3):
  data.iloc[:,i] = data.iloc[:,i].map(df)
data
# Out:
# <ipython-input-73-3e791143d09d>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.iloc[:,i] = data.iloc[:,i].map(df)
#       No               วันที่  Sex  Age  Weight  Height        BMI  \
# 0      1  2022-12-28 00:00:00    1   27    49.0   169.0  17.156262
# 1      2  2022-12-28 00:00:00    1   36    71.0   175.0  23.183673
# 2      3  2022-12-28 00:00:00    2   25    89.0   153.0  38.019565
# 3      4  2022-12-28 00:00:00    1   29    75.0   165.0  27.548209
# 4      5  2022-12-28 00:00:00    1   28   118.0   187.0  33.744173
# ..   ...                  ...  ...  ...     ...     ...        ...
# 188  189           13/05/2023    1   37    88.0   180.0  27.160494
# 189  190           13/05/2023    2   23    47.0   159.0  18.591037
# ...

# %%
data.columns
# Out:
# Index(['No', 'วันที่', 'Sex', 'Age', 'Weight', 'Height', 'BMI',
#        'พื้นที่ทำแบบสอบถาม', 'เวลา', 'Temp', 'Globe temp', '%RH', 'V (m/s)',
#        'วงเล็บ 1', 'สมการหลัง บวก', 'วงเล็บ 2', 'ยกกำลัง 1 ส่วน 4/ 0.25',
#        'ลบ 273.15', 'Thermal acceptance', 'Thermal sensation Vote', 'อุณหภูมิ',
#        'ความชื้น', 'กระแสลม', 'ความแรงของแสงแดด', 'เหงื่อบริเวณผิวหนัง',
#        'ความร้อน', 'ความชื้น.1', 'กระแสลม.1', 'แสงแดด',
#        'เหงื่อบริเวณผิวหนัง.1', 'TMRT'],
#       dtype='object')

# %% [markdown]
# #Decision Tree

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    classification_report,
)

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
X = data[['Sex', 'Age', 'Weight', 'Height', 'BMI']].values
X[0:5]
# Out:
# array([[  1.        ,  27.        ,  49.        , 169.        ,
#          17.15626204],
#        [  1.        ,  36.        ,  71.        , 175.        ,
#          23.18367347],
#        [  2.        ,  25.        ,  89.        , 153.        ,
#          38.01956512],
#        [  1.        ,  29.        ,  75.        , 165.        ,
#          27.54820937],
#        [  1.        ,  28.        , 118.        , 187.        ,
#          33.74417341]])

# %%
y = data["Thermal acceptance"]
y[0:5]
# Out:
# 0    Accept
# 1    Accept
# 2    Accept
# 3    Accept
# 4    Accept
# Name: Thermal acceptance, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.2, random_state=3)

# %%
print(X_trainset.shape)
print(y_trainset.shape)
# Out:
# (154, 5)
# (154,)

# %%
print(X_testset.shape)
print(y_testset.shape)
# Out:
# (39, 5)
# (39,)

# %%
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
drugTree
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
drugTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
predTree = drugTree.predict(X_testset)

# %%
print (predTree [0:5])
print (y_testset [0:5])
# Out:
# ['Accept' 'Accept' 'Unaccept' 'Accept' 'Accept']
# 83     Accept
# 71     Accept
# 190    Accept
# 3      Accept
# 34     Accept
# Name: Thermal acceptance, dtype: object

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.8974358974358975

# %%
f1_1 = f1_score( y_testset , predTree,average = 'weighted')

print("F1 Score:", f1_1)
# Out:
# F1 Score: 0.873180873180873

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
mytree = DecisionTreeClassifier()

# %%
mytree.fit(X_testset,y_testset)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(mytree)
# Out:
# [Text(0.5, 0.875, 'x[3] <= 162.0\ngini = 0.142\nsamples = 39\nvalue = [36, 3]'),
#  Text(0.25, 0.625, 'x[1] <= 26.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.125, 0.375, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.375, 0.375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.75, 0.625, 'x[2] <= 56.0\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.625, 0.375, 'x[4] <= 16.806\ngini = 0.18\nsamples = 10\nvalue = [9, 1]'),
#  Text(0.5, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.125, 'gini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.875, 0.375, 'gini = 0.0\nsamples = 23\nvalue = [23, 0]')]

# %% [markdown]
# #Decision Tree

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

# %%
cols = ['Sex', 'Age', 'Weight', 'Height', 'BMI']

# %%
X = data[cols]
y = data['Thermal acceptance']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=3)

# %%
model = DecisionTreeClassifier(criterion='entropy')

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
X_train.columns
# Out:
# Index(['Sex', 'Age', 'Weight', 'Height', 'BMI'], dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.09395416, 0.22553556, 0.23528473, 0.12094314, 0.3242824 ])

# %%
fs = pd.Series(model.feature_importances_, index = X_train.columns).sort_values(ascending=True)
fs
# Out:
# Sex       0.093954
# Height    0.120943
# Age       0.225536
# Weight    0.235285
# BMI       0.324282
# dtype: float64

# %%
y_train.value_counts()
# Out:
# Accept      137
# Unaccept     17
# Name: Thermal acceptance, dtype: int64

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six

# %%
from six import StringIO

# %%
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image

# %%
dot_data = StringIO()
export_graphviz(model, out_file = dot_data,
                feature_names = cols,
                class_names = ['Accept', 'Unaccept' ],
                filled = True, rounded = True,
                special_characters = True)

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# #SVM

# %%
from sklearn import svm
from sklearn import metrics

# %%
X = data[cols]
y = data['Thermal acceptance']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=3)

# %%
clf = svm.SVC(kernel='linear')

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_2 = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred_2))
# Out:
# Accuracy: 0.8974358974358975

# %%
f1_2 = f1_score(y_test, y_pred_2, average="weighted")

print("F1 Score:", f1_2)
# Out:
# F1 Score: 0.848925848925849

# %% [markdown]
# #Naive Bayes Classifier

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    f1_score,
    classification_report,
)

# %%
X = data[cols]
y = data['Thermal acceptance']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=3)

# %%
model = GaussianNB()

model.fit(X_train, y_train);

# %%
y_pred_3 = model.predict(X_test)

accuray_3 = accuracy_score(y_pred_3, y_test)
f1_3 = f1_score(y_pred_3, y_test, average="weighted")

print("Accuracy:", accuray_3)
print("F1 Score:", f1_3)
# Out:
# Accuracy: 0.8205128205128205
# F1 Score: 0.8118419422767249

# %%
labels = ["Accept", "Unaccept"]
cm = confusion_matrix(y_test, y_pred_3)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=labels)
disp.plot();
