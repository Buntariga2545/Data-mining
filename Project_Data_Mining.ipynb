# %% [markdown]
# <a href="https://colab.research.google.com/github/Buntariga2545/Data-mining/blob/main/Project_Data_Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data = pd.read_excel('/content/drive/My Drive/Paper/Data-Survey-13-7-2023.xlsx')
data
# Out:
#         No               วันที่   เพศ  อายุ  น้ำหนัก  ส่วนสูง        BMI  \
# 0      NaN                  NaN   NaN   NaN      NaN      NaN        NaN
# 1      1.0  2022-12-28 00:00:00   ชาย  27.0     49.0    169.0  17.156262
# 2      2.0  2022-12-28 00:00:00   ชาย  36.0     71.0    175.0  23.183673
# 3      3.0  2022-12-28 00:00:00  หญิง  25.0     89.0    153.0  38.019565
# 4      4.0  2022-12-28 00:00:00   ชาย  29.0     75.0    165.0  27.548209
# ..     ...                  ...   ...   ...      ...      ...        ...
# 189  189.0           13/05/2023   ชาย  37.0     88.0    180.0  27.160494
# 190  190.0           13/05/2023  หญิง  23.0     47.0    159.0  18.591037
# 191  191.0           13/05/2023   ชาย  27.0     47.0    169.0  16.456006
# 192  192.0           13/05/2023   ชาย  57.0     68.0    171.0  23.255019
# 193  193.0           13/05/2023  หญิง  64.0     47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา ค่าที่เครื่องวัดได้  ...  \
# ...

# %%
data = pd.read_excel('/content/drive/My Drive/Paper/Data-Survey-13-7-2023.xlsx', skiprows = 1)
data
# Out:
#      Unnamed: 0           Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0             1  2022-12-28 00:00:00        ชาย          27        49.0
# 1             2  2022-12-28 00:00:00        ชาย          36        71.0
# 2             3  2022-12-28 00:00:00       หญิง          25        89.0
# 3             4  2022-12-28 00:00:00        ชาย          29        75.0
# 4             5  2022-12-28 00:00:00        ชาย          28       118.0
# ..          ...                  ...        ...         ...         ...
# 188         189           13/05/2023        ชาย          37        88.0
# 189         190           13/05/2023       หญิง          23        47.0
# 190         191           13/05/2023        ชาย          27        47.0
# 191         192           13/05/2023        ชาย          57        68.0
# 192         193           13/05/2023       หญิง          64        47.0
#
#      Unnamed: 5  Unnamed: 6            Unnamed: 7 Unnamed: 8  Temp  ...  \
# ...

# %%
data.rename(columns = {'Unnamed: 0' : 'No', 'Unnamed: 1' : 'วันที่', 'Unnamed: 2' : 'เพศ', 'Unnamed: 3' : 'อายุ', 'Unnamed: 4' : 'Weight',
                       'Unnamed: 5' : 'ส่วนสูง', 'Unnamed: 6' : 'BMI', 'Unnamed: 7' : 'พื้นที่ทำแบบสอบถาม', 'Unnamed: 8' : 'เวลา',
                       'Unnamed: 18' : 'Thermal acceptance', 'Unnamed: 26' : 'Thermal sensation Vote'
                       }, inplace = True)
data
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00   ชาย    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00   ชาย    36    71.0    175.0  23.183673
# 2      3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 3      4  2022-12-28 00:00:00   ชาย    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00   ชาย    28   118.0    187.0  33.744173
# ..   ...                  ...   ...   ...     ...      ...        ...
# 188  189           13/05/2023   ชาย    37    88.0    180.0  27.160494
# 189  190           13/05/2023  หญิง    23    47.0    159.0  18.591037
# 190  191           13/05/2023   ชาย    27    47.0    169.0  16.456006
# 191  192           13/05/2023   ชาย    57    68.0    171.0  23.255019
# 192  193           13/05/2023  หญิง    64    47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %%
data.columns
# Out:
# Index([                    'No',                 'วันที่',
#                           'เพศ',                   'อายุ',
#                        'Weight',                'ส่วนสูง',
#                           'BMI',     'พื้นที่ทำแบบสอบถาม',
#                          'เวลา',                   'Temp',
#                    'Globe temp',                    '%RH',
#                       'V (m/s)',               'วงเล็บ 1',
#                 'สมการหลัง บวก',               'วงเล็บ 2',
#        'ยกกำลัง 1 ส่วน 4/ 0.25',              'ลบ 273.15',
#            'Thermal acceptance',                       -3,
#                              -2,                       -1,
#                               0,                     '+1',
#                            '+2',                     '+3',
#        'Thermal sensation Vote',               'อุณหภูมิ',
#                      'ความชื้น',                'กระแสลม',
#              'ความแรงของแสงแดด',    'เหงื่อบริเวณผิวหนัง',
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No                      193 non-null    int64
#  1   วันที่                  193 non-null    object
#  2   เพศ                     193 non-null    object
#  3   อายุ                    193 non-null    int64
#  4   Weight                  192 non-null    float64
#  5   ส่วนสูง                 192 non-null    float64
#  6   BMI                     191 non-null    float64
#  7   พื้นที่ทำแบบสอบถาม      193 non-null    object
#  8   เวลา                    193 non-null    object
#  9   Temp                    193 non-null    float64
#  10  Globe temp              193 non-null    float64
#  11  %RH                     193 non-null    float64
#  12  V (m/s)                 193 non-null    float64
#  13  วงเล็บ 1                193 non-null    int64
# ...

# %%
data.isnull().sum()
# Out:
# No                          0
# วันที่                      0
# เพศ                         0
# อายุ                        0
# Weight                      1
# ส่วนสูง                     1
# BMI                         2
# พื้นที่ทำแบบสอบถาม          0
# เวลา                        0
# Temp                        0
# Globe temp                  0
# %RH                         0
# V (m/s)                     0
# วงเล็บ 1                    0
# สมการหลัง บวก               0
# วงเล็บ 2                    0
# ยกกำลัง 1 ส่วน 4/ 0.25      0
# ลบ 273.15                   0
# Thermal acceptance          0
# -3                        193
# -2                        189
# -1                        154
# 0                         134
# +1                        140
# +2                        171
# +3                        177
# Thermal sensation Vote      0
# อุณหภูมิ                    0
# ความชื้น                    0
# กระแสลม                     0
# ความแรงของแสงแดด            0
# ...

# %%
data1 = data.drop(127)

# %%
data2 = data1.drop(165)

# %%
data3 = data2.drop(157)

# %% [markdown]
# ###ทำการ clean data ตัดข้อมูลค่าว่าง 2 แถว กับค่า outlier 1 แถว

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 190 entries, 0 to 192
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   No                      190 non-null    int64
#  1   วันที่                  190 non-null    object
#  2   เพศ                     190 non-null    object
#  3   อายุ                    190 non-null    int64
#  4   Weight                  190 non-null    float64
#  5   ส่วนสูง                 190 non-null    float64
#  6   BMI                     190 non-null    float64
#  7   พื้นที่ทำแบบสอบถาม      190 non-null    object
#  8   เวลา                    190 non-null    object
#  9   Temp                    190 non-null    float64
#  10  Globe temp              190 non-null    float64
#  11  %RH                     190 non-null    float64
#  12  V (m/s)                 190 non-null    float64
#  13  วงเล็บ 1                190 non-null    int64
# ...

# %% [markdown]
# ###พบว่าข้อมูลที่เป็นอายุเป็นตัวเลข โดยอายุเป็น int น้ำหนักตัว เป็น float ซึ่งก็เหมาะสมกับข้อมูลแล้ว

# %%
data3.describe()
# Out:
#                No        อายุ      Weight     ส่วนสูง         BMI        Temp  \
# count  190.000000  190.000000  190.000000  190.000000  190.000000  190.000000
# mean    96.152632   30.536842   68.131579  167.300000   24.237014   30.860526
# std     55.848083   11.880633   21.725769    9.781177    6.924044    2.310997
# min      1.000000   20.000000   41.000000  144.000000   16.015625   27.200000
# 25%     48.250000   25.000000   49.000000  158.250000   19.146722   29.100000
# 50%     95.500000   27.000000   63.000000  169.000000   22.222333   30.800000
# 75%    143.750000   35.750000   75.000000  173.000000   27.451280   32.700000
# max    193.000000   70.000000  120.000000  187.000000   38.019565   35.600000
#
#        Globe temp         %RH     V (m/s)      วงเล็บ 1  ...    อุณหภูมิ  \
# count  190.000000  190.000000  190.000000  1.900000e+02  ...  190.000000
# mean    31.501053   48.602105    0.265974  8.617410e+09  ...    2.542105
# ...

# %%
set(data3['พื้นที่ทำแบบสอบถาม'])
# Out:
# {'ภายนอก / ใต้ร่มไม้',
#  'ภายนอก กลางแจ้ง',
#  'ภายนอก/ กลางแจ้ง',
#  'ภายนอก/ มีหลังคาคลุม',
#  'ภายใต้ร่มไม้',
#  'ภายใต้อาคาร'}

# %%
data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายใต้ร่มไม้'] = 'ภายนอก / ใต้ร่มไม้'
data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก กลางแจ้ง'] = 'ภายนอก/ กลางแจ้ง'
# Out:
# <ipython-input-14-9efe923acf1c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายใต้ร่มไม้'] = 'ภายนอก / ใต้ร่มไม้'
# <ipython-input-14-9efe923acf1c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['พื้นที่ทำแบบสอบถาม'][data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก กลางแจ้ง'] = 'ภายนอก/ กลางแจ้ง'

# %%
set(data3['พื้นที่ทำแบบสอบถาม'])
# Out:
# {'ภายนอก / ใต้ร่มไม้',
#  'ภายนอก/ กลางแจ้ง',
#  'ภายนอก/ มีหลังคาคลุม',
#  'ภายใต้อาคาร'}

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %%
figure, axis = plt.subplots(2, 2)

axis[0, 0].hist(data3['Temp'][data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก / ใต้ร่มไม้'], color='red', alpha=0.5)
axis[0, 0].set_title('ภายนอก / ใต้ร่มไม้')
axis[0, 1].hist(data3['Temp'][data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ กลางแจ้ง'], color='green', alpha=0.5)
axis[0, 1].set_title('ภายนอก/ กลางแจ้ง')
axis[1, 0].hist(data3['Temp'][data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ มีหลังคาคลุม'], color='purple', alpha=0.5)
axis[1, 0].set_title('ภายนอก/ มีหลังคาคลุม')
axis[1, 1].hist(data3['Temp'][data3['พื้นที่ทำแบบสอบถาม']=='ภายใต้อาคาร'], color='blue', alpha=0.5)
axis[1, 1].set_title('ภายใต้อาคาร')
plt.legend(loc='upper right')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data3['เพศ'].value_counts()
# Out:
# ชาย     122
# หญิง     68
# Name: เพศ, dtype: int64

# %%
df = data3.groupby('เพศ').mean()
df
# Out:
# <ipython-input-24-b9e07cec8526>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df = data3.groupby('เพศ').mean()
#               No       อายุ     Weight     ส่วนสูง        BMI       Temp  \
# เพศ
# ชาย    82.385246  28.500000  70.991803  173.303279  23.343620  30.308197
# หญิง  120.852941  34.191176  63.000000  156.529412  25.839867  31.851471
#
#       Globe temp        %RH   V (m/s)      วงเล็บ 1  ...  อุณหภูมิ  ความชื้น  \
# เพศ                                                  ...
# ชาย    30.940984  46.455738  0.272787  8.553826e+09  ...  2.254098  1.909836
# หญิง   32.505882  52.452941  0.253750  8.731485e+09  ...  3.058824  2.073529
#
#        กระแสลม  ความแรงของแสงแดด  เหงื่อบริเวณผิวหนัง  ความร้อน  ความชื้น.1  \
# เพศ
# ...

# %%
data3['เพศ'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='เพศ'>

# %% [markdown]
# ###แสดงแผนภูมิวงกลมเพศชายและเพศหญิง

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
set(data3['พื้นที่ทำแบบสอบถาม'])
# Out:
# {'ภายนอก / ใต้ร่มไม้',
#  'ภายนอก/ กลางแจ้ง',
#  'ภายนอก/ มีหลังคาคลุม',
#  'ภายใต้อาคาร'}

# %%
data3[(data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ มีหลังคาคลุม')]
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00   ชาย    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00   ชาย    36    71.0    175.0  23.183673
# 2      3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 3      4  2022-12-28 00:00:00   ชาย    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00   ชาย    28   118.0    187.0  33.744173
# ..   ...                  ...   ...   ...     ...      ...        ...
# 118  119  2023-01-06 00:00:00   ชาย    36    71.0    175.0  23.183673
# 119  120  2023-01-06 00:00:00   ชาย    20    63.0    173.0  21.049818
# 120  121  2023-01-06 00:00:00   ชาย    27    49.0    169.0  17.156262
# 121  122  2023-01-06 00:00:00  หญิง    25    89.0    153.0  38.019565
# 122  123  2023-01-06 00:00:00   ชาย    36    71.0    175.0  23.183673
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %%
data3[(data3['พื้นที่ทำแบบสอบถาม']=='ภายนอก/ มีหลังคาคลุม') | (data3['พื้นที่ทำแบบสอบถาม']=='ภายใต้อาคาร')]
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00   ชาย    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00   ชาย    36    71.0    175.0  23.183673
# 2      3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 3      4  2022-12-28 00:00:00   ชาย    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00   ชาย    28   118.0    187.0  33.744173
# ..   ...                  ...   ...   ...     ...      ...        ...
# 188  189           13/05/2023   ชาย    37    88.0    180.0  27.160494
# 189  190           13/05/2023  หญิง    23    47.0    159.0  18.591037
# 190  191           13/05/2023   ชาย    27    47.0    169.0  16.456006
# 191  192           13/05/2023   ชาย    57    68.0    171.0  23.255019
# 192  193           13/05/2023  หญิง    64    47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %%
data3.groupby(['พื้นที่ทำแบบสอบถาม'])[['No']].count().\
sort_values(by=['No'],ascending=False)
# Out:
#                        No
# พื้นที่ทำแบบสอบถาม
# ภายนอก/ มีหลังคาคลุม  107
# ภายใต้อาคาร            50
# ภายนอก/ กลางแจ้ง       18
# ภายนอก / ใต้ร่มไม้     15

# %%
data3.groupby(['พื้นที่ทำแบบสอบถาม'])[['No']].count().\
sort_values(by=['No'],ascending=False).plot.bar(color='purple')
# Out:
# <Axes: xlabel='พื้นที่ทำแบบสอบถาม'>

# %% [markdown]
# ###แสดงแผนภูมิวงกลมพื้นที่ทำแบบสอบถามทั้ง 4 บริเวณ

# %%
data3.groupby(['อายุ'])[['No']].count().\
sort_values(by=['No'],ascending=False)
# Out:
#       No
# อายุ
# 20    39
# 27    36
# 25    30
# 28    20
# 36    18
# 29     5
# 23     4
# 24     3
# 62     3
# 37     3
# 46     2
# 60     2
# 49     2
# 35     2
# 26     2
# 44     1
# 59     1
# 69     1
# 67     1
# 66     1
# 64     1
# 63     1
# 61     1
# 31     1
# 58     1
# 45     1
# 57     1
# 56     1
# 54     1
# 53     1
# 52     1
# 47     1
# 38     1
# 70     1

# %%
data3['อายุ'].value_counts().sort_index().plot(kind='bar', figsize=(16, 4), color='blue')
# Out:
# <Axes: >

# %%
data3.groupby(['อายุ'])[['No']].count().\
sort_values(by=['No'],ascending=False).iloc[0:5].plot.bar(color='blue')
# Out:
# <Axes: xlabel='อายุ'>

# %% [markdown]
# ###แผนภูมิแท่งแสดงอายุจำนวนคนที่ทำแบบสอบถามเรียงจากมากไปน้อย

# %%
data3.groupby(['Temp'])[['No']].count().\
sort_values(by=['No'],ascending=False)
# Out:
#       No
# Temp
# 27.7  13
# 29.1  11
# 33.7  11
# 30.8  10
# 35.6   9
# 30.4   8
# 32.7   8
# 33.1   8
# 28.3   8
# 35.2   7
# 32.9   6
# 32.2   6
# 29.4   6
# 31.4   5
# 31.3   5
# 31.2   5
# 31.1   5
# 30.9   5
# 27.2   5
# 27.5   5
# 30.5   5
# 30.2   5
# 28.1   5
# 32.6   4
# 29.9   3
# 29.5   3
# 32.1   3
# 29.3   3
# 29.2   3
# 29.0   3
# 28.9   3
# 30.7   2
# 34.5   1
# 27.8   1

# %%
data3['Temp'].value_counts().sort_index().plot(kind='bar', figsize=(16, 4), color='green')
# Out:
# <Axes: >

# %%
data3.groupby(['Temp'])[['No']].count().\
sort_values(by=['No'],ascending=False).iloc[0:5].plot.bar(color='purple')
# Out:
# <Axes: xlabel='Temp'>

# %% [markdown]
# ###แผนภูมิแท่งแสดงอุณหภูมิบริเวณที่ทำแบบสอบถามเรียงจากมากไปน้อย

# %%
data3.groupby(['Globe temp'])[['No']].count().\
sort_values(by=['No'],ascending=False)
# Out:
#             No
# Globe temp
# 27.8        16
# 32.2        15
# 34.4        14
# 35.3        12
# 30.1        12
# 30.6        10
# 31.2        10
# 31.9        10
# 36.2         9
# 28.9         8
# 32.5         8
# 28.8         6
# 33.1         6
# 31.8         5
# 34.2         5
# 32.3         5
# 27.6         5
# 28.1         5
# 31.4         5
# 32.9         4
# 31.5         3
# 30.4         3
# 30.0         3
# 29.8         3
# 29.4         3
# 28.6         2
# 33.2         1
# 28.7         1
# 34.6         1

# %%
data3['Globe temp'].value_counts().sort_index().plot(kind='bar', figsize=(16, 4), color='purple')
# Out:
# <Axes: >

# %%
data3.groupby(['Globe temp'])[['No']].count().\
sort_values(by=['No'],ascending=False).iloc[0:5].plot.bar(color='purple')
# Out:
# <Axes: xlabel='Globe temp'>

# %% [markdown]
# ###แผนภูมิแท่งแสดงอุณหภูมิทั่วไปเรียงจากมากไปน้อย

# %%
data3['Temp'].hist(label="Temp", alpha=0.5)
data3['Globe temp'].hist(label="Globe temp", alpha=0.5)
plt.legend(loc='upper right')

# %%
data3.plot.line(x='วันที่', y={'Temp', 'Globe temp', '%RH'})
# Out:
# <ipython-input-86-70f104badac9>:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   data3.plot.line(x='วันที่', y={'Temp', 'Globe temp', '%RH'})
# <Axes: xlabel='วันที่'>

# %%
data3[data3['Thermal acceptance']=='Accept']
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00   ชาย    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00   ชาย    36    71.0    175.0  23.183673
# 2      3  2022-12-28 00:00:00  หญิง    25    89.0    153.0  38.019565
# 3      4  2022-12-28 00:00:00   ชาย    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00   ชาย    28   118.0    187.0  33.744173
# ..   ...                  ...   ...   ...     ...      ...        ...
# 187  188           13/05/2023   ชาย    27    72.0    171.0  24.622961
# 188  189           13/05/2023   ชาย    37    88.0    180.0  27.160494
# 190  191           13/05/2023   ชาย    27    47.0    169.0  16.456006
# 191  192           13/05/2023   ชาย    57    68.0    171.0  23.255019
# 192  193           13/05/2023  หญิง    64    47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %%
data3[data3['Thermal acceptance']=='Unaccept']
# Out:
#       No               วันที่   เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 97    98  2023-01-06 00:00:00  หญิง    20    46.0    155.0  19.146722
# 98    99  2023-01-06 00:00:00   ชาย    27    49.0    169.0  17.156262
# 99   100  2023-01-06 00:00:00   ชาย    20    63.0    173.0  21.049818
# 104  105  2023-01-06 00:00:00   ชาย    36    71.0    175.0  23.183673
# 140  141           13/05/2023   ชาย    45    70.0    177.0  22.343516
# 141  142           13/05/2023  หญิง    53    56.0    154.0  23.612751
# 148  149           13/05/2023  หญิง    52    52.0    154.0  21.926126
# 149  150           13/05/2023  หญิง    27    54.0    161.0  20.832530
# 155  156           13/05/2023  หญิง    25    50.0    163.0  18.818924
# 173  174           13/05/2023  หญิง    23    49.0    161.0  18.903592
# 174  175           13/05/2023  หญิง    67    51.0    150.0  22.666667
# 175  176           13/05/2023   ชาย    27    46.0    169.0  16.105879
# ...

# %%
count_pv_onset = data3.groupby('Thermal acceptance')[['No']].count().sort_values('No', ascending=False)
count_pv_onset
# Out:
#                      No
# Thermal acceptance
# Accept              169
# Unaccept             21

# %%
count_pv_onset.plot.pie(y='No')
# Out:
# <Axes: ylabel='No'>

# %% [markdown]
# ###แผนภูมิวงกลมแสดงการยอมรับสภาพอากาศและไม่ยอมรับสภาพอากาศ

# %%
df = {'ชาย':1, 'หญิง':2}
temp = data3.copy()
for i in range(2,3):
  temp.iloc[:,i] = temp.iloc[:,i].map(df)
temp
# Out:
# <ipython-input-27-c5221a95eff4>:4: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   temp.iloc[:,i] = temp.iloc[:,i].map(df)
#       No               วันที่  เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00    1    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00    1    36    71.0    175.0  23.183673
# 2      3  2022-12-28 00:00:00    2    25    89.0    153.0  38.019565
# 3      4  2022-12-28 00:00:00    1    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00    1    28   118.0    187.0  33.744173
# ..   ...                  ...  ...   ...     ...      ...        ...
# 188  189           13/05/2023    1    37    88.0    180.0  27.160494
# 189  190           13/05/2023    2    23    47.0    159.0  18.591037
# ...

# %%
temp
# Out:
#       No               วันที่  เพศ  อายุ  Weight  ส่วนสูง        BMI  \
# 0      1  2022-12-28 00:00:00    1    27    49.0    169.0  17.156262
# 1      2  2022-12-28 00:00:00    1    36    71.0    175.0  23.183673
# 2      3  2022-12-28 00:00:00    2    25    89.0    153.0  38.019565
# 3      4  2022-12-28 00:00:00    1    29    75.0    165.0  27.548209
# 4      5  2022-12-28 00:00:00    1    28   118.0    187.0  33.744173
# ..   ...                  ...  ...   ...     ...      ...        ...
# 188  189           13/05/2023    1    37    88.0    180.0  27.160494
# 189  190           13/05/2023    2    23    47.0    159.0  18.591037
# 190  191           13/05/2023    1    27    47.0    169.0  16.456006
# 191  192           13/05/2023    1    57    68.0    171.0  23.255019
# 192  193           13/05/2023    2    64    47.0    149.0  21.170218
#
#        พื้นที่ทำแบบสอบถาม      เวลา  Temp  ...  อุณหภูมิ  ความชื้น  กระแสลม  \
# ...

# %%
temp.corr()
# Out:
# <ipython-input-29-79cec36d1758>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   temp.corr()
#                               No       เพศ      อายุ    Weight   ส่วนสูง  \
# No                      1.000000  0.331066  0.371277 -0.269228 -0.234017
# เพศ                     0.331066  1.000000  0.230244 -0.176806 -0.824269
# อายุ                    0.371277  0.230244  1.000000 -0.080343 -0.245576
# Weight                 -0.269228 -0.176806 -0.080343  1.000000  0.437627
# ส่วนสูง                -0.234017 -0.824269 -0.245576  0.437627  1.000000
# BMI                    -0.209030  0.173282 -0.004136  0.895798  0.009671
# Temp                    0.792320  0.320974  0.426390 -0.183007 -0.224603
# Globe temp              0.724275  0.308598  0.357575 -0.182303 -0.228008
# ...

# %%
dcorr = temp.corr()
dcorr
# Out:
# <ipython-input-30-e9ab692d9529>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dcorr = temp.corr()
#                               No       เพศ      อายุ    Weight   ส่วนสูง  \
# No                      1.000000  0.331066  0.371277 -0.269228 -0.234017
# เพศ                     0.331066  1.000000  0.230244 -0.176806 -0.824269
# อายุ                    0.371277  0.230244  1.000000 -0.080343 -0.245576
# Weight                 -0.269228 -0.176806 -0.080343  1.000000  0.437627
# ส่วนสูง                -0.234017 -0.824269 -0.245576  0.437627  1.000000
# BMI                    -0.209030  0.173282 -0.004136  0.895798  0.009671
# Temp                    0.792320  0.320974  0.426390 -0.183007 -0.224603
# Globe temp              0.724275  0.308598  0.357575 -0.182303 -0.228008
# ...

# %%
dcorr.style.background_gradient()
# Out:
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3931: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/style.py:3932: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_7b7c4_row0_col0, #T_7b7c4_row1_col1, #T_7b7c4_row2_col2, #T_7b7c4_row3_col3, #T_7b7c4_row4_col4, #T_7b7c4_row5_col5, #T_7b7c4_row6_col6, #T_7b7c4_row7_col7, #T_7b7c4_row7_col10, #T_7b7c4_row8_col8, #T_7b7c4_row9_col9, #T_7b7c4_row10_col7, #T_7b7c4_row10_col10, #T_7b7c4_row10_col13, #T_7b7c4_row11_col11, #T_7b7c4_row12_col12, #T_7b7c4_row13_col10, #T_7b7c4_row13_col13, #T_7b7c4_row22_col22, #T_7b7c4_row23_col23, #T_7b7c4_row24_col24, #T_7b7c4_row25_col25, #T_7b7c4_row26_col26, #T_7b7c4_row27_col27, #T_7b7c4_row28_col28, #T_7b7c4_row29_col29, #T_7b7c4_row30_col30, #T_7b7c4_row31_col31, #T_7b7c4_row32_col32 {
# ...

# %% [markdown]
# ###correlation แสดงความสัมพันธ์
